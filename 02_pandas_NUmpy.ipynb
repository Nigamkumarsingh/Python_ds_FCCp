# %%
import random
import pandas as pd
import numpy as np
df = pd.read_csv('StudentsPerformance.csv')

# %%
#sort descending by index
df.sort_index(ascending=False,inplace=True)
df.head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 999                    none          77             86             86
# 998               completed          68             78             77
# 997               completed          59             71             65
# 996                    none          62             55             55
# 995               completed          88             99             95

# %%
#rename one column
df = df.rename(columns={'gender':'Gender'})
df.head()
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 999                    none          77             86             86
# 998               completed          68             78             77
# 997               completed          59             71             65
# 996                    none          62             55             55
# 995               completed          88             99             95

# %%
#rename multiple columns
df = df.rename(columns= {'math score':'Maths_score',
                        'reading score':'Reading_score',
                        'writing score':'Writing_Score'})
df.head()
# Out:
#      Gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  Maths_score  Reading_score  Writing_Score
# 999                    none           77             86             86
# 998               completed           68             78             77
# 997               completed           59             71             65
# 996                    none           62             55             55
# 995               completed           88             99             95

# %%
#rename index  0 1 and 2 and update df
df = pd.read_csv('StudentsPerformance.csv')
df.rename(index={0:'A',1:'B',2:'C'},inplace=True)
df.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# A  female        group B           bachelor's degree  standard
# B  female        group C                some college  standard
# C  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score
# A                    none          72             72             74
# B               completed          69             90             88
# C                    none          90             95             93
